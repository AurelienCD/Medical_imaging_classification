# %% [markdown]
# <a href="https://colab.research.google.com/github/AurelienCD/Medical_imaging_classification/blob/main/notebook_classification_CIRS_80kv_140kv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-

# %% [markdown]
# Connexion au google drive, déplacement dans le dossier contenant les données nécessaires au projet

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/Projet scan classification UH
# Out:
# /content/drive/MyDrive/Projet scan classification UH

# %% [markdown]
# Importation des librairies nécessaires au projet

# %%
import pandas as pad 
import numpy as np
from numpy.core.numeric import NaN

import datetime

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

from sklearn.cluster import DBSCAN
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import silhouette_score

from mpl_toolkits.mplot3d import Axes3D

from sklearn.metrics.cluster import adjusted_rand_score

# %%
df = pad.read_csv('extractionCIRS.csv', sep=';')

# %%
df
# Out:
#         label      70      80     100  120      140
# 0           1 -313.34 -329.78 -353.33 -349 -267.090
# 1           1 -350.15 -338.68 -356.40 -339 -263.650
# 2           1 -352.48 -332.41 -363.07 -356 -264.470
# 3           1 -293.85 -329.68 -345.94 -358 -256.740
# 4           1 -329.91 -298.65 -340.04 -345 -256.410
# ...       ...     ...     ...     ...  ...      ...
# 163115     17  -57.30  -18.70   35.30  -12  -13.300
# 163116     17   -3.25   12.60   23.50   14  -18.500
# 163117     17  -12.40    3.13   54.70  -10   15.100
# 163118     17  -21.40  -43.90   21.40  -12    2.000
# 163119     17  -34.80  -25.00    5.90   18    0.474
#
# [163120 rows x 6 columns]

# %%
custom_palette = [sns.xkcd_rgb["windows blue"], sns.xkcd_rgb["pale red"], sns.xkcd_rgb["medium green"], "orange", "blue","yellow", "purple", "deeppink", "brown", "teal", "black", sns.xkcd_rgb["windows blue"], sns.xkcd_rgb["pale red"], sns.xkcd_rgb["medium green"], "orange", "blue","yellow"] 
sns.set_palette(custom_palette)

# %%
color = sns.color_palette()

# %%
sns.pairplot(df.drop(columns=['label']))

# %%
sns.pairplot(df, hue="label", palette = custom_palette)

# %%
df_UH_energy = df[["80", "140"]]

# %%
df_UH_energy = df_UH_energy.dropna()

# %%
df_UH_energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163120 entries, 0 to 163119
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   80      163120 non-null  float64
#  1   140     163120 non-null  float64
# dtypes: float64(2)
# memory usage: 3.7 MB

# %% [markdown]
# ### Préparation des données

# %%
df_UH_energy.columns
# Out:
# Index(['80', '140'], dtype='object')

# %% [markdown]
# Préparation des données quantitatives (standardisation)

# %%
df_UH_energy_scaler = StandardScaler().fit_transform(df_UH_energy)
df_UH_energy_norm = pad.DataFrame(columns = df_UH_energy.columns, data = df_UH_energy_scaler).set_index(df_UH_energy.index)

# %%
df_UH_energy_norm
# Out:
#               80       140
# 0      -0.642862 -0.438277
# 1      -0.671442 -0.426882
# 2      -0.651308 -0.429598
# 3      -0.642541 -0.403992
# 4      -0.542897 -0.402898
# ...          ...       ...
# 163115  0.356089  0.402426
# 163116  0.456601  0.385200
# 163117  0.426191  0.496503
# 163118  0.275166  0.453109
# 163119  0.335858  0.448054
#
# [163120 rows x 2 columns]

# %% [markdown]
# Faute de mémoire suffisante, je ne prend qu'une partie du dataset

# %%
df_UH_energy_norm_sample = df_UH_energy_norm.sample(int(df_UH_energy_norm.shape[0]/10), random_state=7).copy()

# %% [markdown]
# # Segmentation des inserts par KMeans

# %% [markdown]
# ### Kmeans

# %%
inertia = {}
dict_kmeans = {}
for k in range(1,10):
    kmeans = KMeans(n_clusters=k, verbose=1, random_state=7).fit(df_UH_energy_norm_sample)
    inertia[k] = kmeans.inertia_
    dict_kmeans[k] = kmeans
# Out:
# Initialization complete
# Iteration 0, inertia 44173.596094645705.
# Iteration 1, inertia 32804.40766233976.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 38573.33483933826.
# Iteration 1, inertia 32804.40766233976.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 43483.75012542639.
# Iteration 1, inertia 32804.40766233976.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 36473.59247310002.
# Iteration 1, inertia 32804.40766233976.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 74241.77026094572.
# Iteration 1, inertia 32804.40766233976.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 79648.03044123304.
# Iteration 1, inertia 32804.40766233976.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 45972.30663976977.
# Iteration 1, inertia 32804.40766233976.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 74932.33095355524.
# Iteration 1, inertia 32804.40766233976.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 44519.56312371547.
# Iteration 1, inertia 32804.40766233976.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 76221.92965142362.
# Iteration 1, inertia 32804.40766233976.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 6284.1644429755725
# Iteration 1, inertia 4548.070597300116
# Converged at iteration 1: center shift 2.7060550034293406e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 17529.798272963122
# Iteration 1, inertia 4548.070597300116
# Converged at iteration 1: center shift 2.7060550034293406e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 6508.966098558154
# Iteration 1, inertia 4548.265924967738
# Converged at iteration 1: center shift 6.084107512074446e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 10759.38108623154
# Iteration 1, inertia 4551.886416105799
# Iteration 2, inertia 4547.946179937885
# Converged at iteration 2: center shift 1.3719804745358854e-06 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 6867.668618375092
# Iteration 1, inertia 4548.070597300116
# Converged at iteration 1: center shift 2.7060550034293406e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 9581.433286169871
# Iteration 1, inertia 4549.8595997451785
# Iteration 2, inertia 4547.946179937885
# Converged at iteration 2: center shift 1.3719804745358854e-06 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 6820.682834643118
# Iteration 1, inertia 4548.070597300116
# Converged at iteration 1: center shift 2.7060550034293406e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 10198.653282348285
# Iteration 1, inertia 4549.33525672495
# Iteration 2, inertia 4547.946179937885
# Converged at iteration 2: center shift 1.3719804745358854e-06 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 5185.34037142424
# Iteration 1, inertia 4547.98597177816
# Converged at iteration 1: center shift 9.229906935709676e-06 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 6725.021565038285
# Iteration 1, inertia 4548.070597300116
# Converged at iteration 1: center shift 2.7060550034293406e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 2866.692279496454
# Iteration 1, inertia 2766.2975402454103
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 2889.989175673836
# Iteration 1, inertia 2766.2975402454103
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 3403.3946268287286
# Iteration 1, inertia 2766.2975402454103
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 4527.563779655622
# Iteration 1, inertia 2416.3596587241573
# Iteration 2, inertia 2415.787812730733
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 2788.6243066491197
# Iteration 1, inertia 2766.2975402454103
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 3265.718350560769
# Iteration 1, inertia 2415.966339864978
# Converged at iteration 1: center shift 3.3313590434514585e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 2968.9223132718707
# Iteration 1, inertia 2766.2975402454103
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 3717.030432967864
# Iteration 1, inertia 2416.362695469992
# Iteration 2, inertia 2415.787812730733
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 3247.961160518709
# Iteration 1, inertia 2415.992498525583
# Converged at iteration 1: center shift 3.8274149569241324e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 2852.0996288131328
# Iteration 1, inertia 2766.2975402454103
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 1884.8907230557938
# Iteration 1, inertia 1312.878120372357
# Iteration 2, inertia 1186.6766433227904
# Iteration 3, inertia 985.484058224067
# Iteration 4, inertia 668.4970695863396
# Iteration 5, inertia 643.2920182278908
# Converged at iteration 5: center shift 5.542184676419704e-06 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 1074.7287257276976
# Iteration 1, inertia 643.3812191586014
# Converged at iteration 1: center shift 3.548790400012733e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 796.4583830219951
# Iteration 1, inertia 643.2835699223324
# Converged at iteration 1: center shift 1.6173919213892593e-06 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 806.9316758752602
# Iteration 1, inertia 643.3812191586014
# Converged at iteration 1: center shift 3.548790400012733e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 918.6655748758617
# Iteration 1, inertia 643.396277603156
# Converged at iteration 1: center shift 4.137278680596339e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 746.2347784222105
# Iteration 1, inertia 643.3538597657252
# Converged at iteration 1: center shift 2.4696580388044464e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 1283.0533556390983
# Iteration 1, inertia 643.2801009283698
# Converged at iteration 1: center shift 3.2245408096913096e-07 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 1483.7144161291449
# Iteration 1, inertia 643.4577693656563
# Converged at iteration 1: center shift 6.502007508405636e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 725.1360079624129
# Iteration 1, inertia 643.29395419204
# Converged at iteration 1: center shift 6.078222477723527e-06 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 688.7645566638214
# Iteration 1, inertia 643.2793438105349
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 310.71372716632044
# Iteration 1, inertia 280.82497025569853
# Iteration 2, inertia 280.0141570519378
# Converged at iteration 2: center shift 3.2894261666015014e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 383.3126722612891
# Iteration 1, inertia 297.0492586009158
# Iteration 2, inertia 286.16830867795585
# Iteration 3, inertia 282.0332398257027
# Iteration 4, inertia 280.5699394119365
# Converged at iteration 4: center shift 6.879606043162777e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 627.5920189371554
# Iteration 1, inertia 280.35955754417387
# Converged at iteration 1: center shift 9.398671043729378e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 347.6187888491745
# Iteration 1, inertia 280.9002168895259
# Iteration 2, inertia 280.0581738628366
# Converged at iteration 2: center shift 3.7476351505008665e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 493.6625556799766
# Iteration 1, inertia 305.1041263402174
# Iteration 2, inertia 289.60299454889645
# Iteration 3, inertia 283.4665120409775
# Iteration 4, inertia 281.1118302432088
# Iteration 5, inertia 280.1852565786872
# Converged at iteration 5: center shift 5.278816204657615e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 399.53084985015073
# Iteration 1, inertia 279.5927369390807
# Converged at iteration 1: center shift 5.112917046945471e-06 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 350.6261807465556
# Iteration 1, inertia 283.51992562269163
# Iteration 2, inertia 281.13501816776136
# Iteration 3, inertia 280.18927194018033
# Converged at iteration 3: center shift 5.28094323104569e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 566.6121345202869
# Iteration 1, inertia 279.617945490971
# Converged at iteration 1: center shift 1.1464678050845672e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 398.5724823629679
# Iteration 1, inertia 282.37500476993927
# Iteration 2, inertia 280.7045138333892
# Converged at iteration 2: center shift 7.814308126984395e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 355.9598407345603
# Iteration 1, inertia 280.6303266430247
# Converged at iteration 1: center shift 9.250545864828815e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 273.66512072556645
# Iteration 1, inertia 222.51226852696283
# Iteration 2, inertia 206.22828200158148
# Iteration 3, inertia 196.78938748418625
# Iteration 4, inertia 193.5868916586086
# Iteration 5, inertia 192.77184077546053
# Converged at iteration 5: center shift 3.6715651374145136e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 373.9330097877141
# Iteration 1, inertia 193.28221606169276
# Iteration 2, inertia 192.5535193287107
# Converged at iteration 2: center shift 4.481142710370305e-06 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 274.5839087633751
# Iteration 1, inertia 201.34301834889436
# Iteration 2, inertia 194.4295313270121
# Iteration 3, inertia 192.9358133986649
# Converged at iteration 3: center shift 6.167914240636035e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 411.058268131844
# Iteration 1, inertia 193.36024345312103
# Iteration 2, inertia 192.72230117205677
# Converged at iteration 2: center shift 3.022513131363177e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 224.1739636507027
# Iteration 1, inertia 192.77999824410796
# Converged at iteration 1: center shift 5.261179473288242e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 310.6124951749428
# Iteration 1, inertia 193.95396056558707
# Iteration 2, inertia 192.6276709751407
# Converged at iteration 2: center shift 2.2725588026351285e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 358.0045581952314
# Iteration 1, inertia 197.73986747991614
# Iteration 2, inertia 194.26541210346045
# Iteration 3, inertia 192.9996221463847
# Converged at iteration 3: center shift 8.801171307516959e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 280.90716227285634
# Iteration 1, inertia 199.6642500218282
# Iteration 2, inertia 195.02360616583042
# Iteration 3, inertia 193.2585012409345
# Iteration 4, inertia 192.69129564290023
# Converged at iteration 4: center shift 2.648926205804092e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 359.07175919298777
# Iteration 1, inertia 210.4605675122541
# Iteration 2, inertia 201.1261026178364
# Iteration 3, inertia 195.91054766275144
# Iteration 4, inertia 193.58984329636712
# Iteration 5, inertia 192.78527622714233
# Converged at iteration 5: center shift 4.4502799478891626e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 231.76050702218748
# Iteration 1, inertia 195.43910733396726
# Iteration 2, inertia 193.39593384400234
# Iteration 3, inertia 192.72303390565193
# Converged at iteration 3: center shift 3.2520480050536927e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 223.85540936422825
# Iteration 1, inertia 181.08928324238758
# Iteration 2, inertia 176.58866438862873
# Iteration 3, inertia 175.36554618813523
# Iteration 4, inertia 174.97049123450472
# Converged at iteration 4: center shift 7.279646179357139e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 387.44194712754177
# Iteration 1, inertia 231.93646420125225
# Iteration 2, inertia 215.0931509521695
# Iteration 3, inertia 200.712240756562
# Iteration 4, inertia 188.53663214570145
# Iteration 5, inertia 180.2551095898395
# Iteration 6, inertia 175.6761236833791
# Iteration 7, inertia 173.71499858264937
# Iteration 8, inertia 173.01987530003896
# Converged at iteration 8: center shift 6.325620134225402e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 269.2987319385722
# Iteration 1, inertia 185.1248857906188
# Iteration 2, inertia 176.66566088454567
# Iteration 3, inertia 173.90253094858897
# Iteration 4, inertia 173.1632083101699
# Converged at iteration 4: center shift 7.879798782015987e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 244.89439933670454
# Iteration 1, inertia 182.72213072456486
# Iteration 2, inertia 177.01540101642598
# Iteration 3, inertia 175.69167900301898
# Converged at iteration 3: center shift 8.398229594023981e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 298.2874654490502
# Iteration 1, inertia 167.84222852738912
# Iteration 2, inertia 167.72381199802277
# Converged at iteration 2: center shift 1.2594346636948843e-06 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 332.4201225514241
# Iteration 1, inertia 177.63225516154793
# Iteration 2, inertia 170.32737227417536
# Iteration 3, inertia 168.8857529721597
# Iteration 4, inertia 168.41248786772167
# Iteration 5, inertia 168.07446769174274
# Iteration 6, inertia 167.7869715095888
# Iteration 7, inertia 167.7298860219013
# Iteration 8, inertia 167.7170876871001
# Converged at iteration 8: center shift 1.3361758626013963e-07 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 221.56815397785522
# Iteration 1, inertia 191.08158539996623
# Iteration 2, inertia 182.1991465473857
# Iteration 3, inertia 178.26780447161548
# Iteration 4, inertia 176.78569786312028
# Iteration 5, inertia 176.28270986326834
# Converged at iteration 5: center shift 4.176290365628626e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 217.43844698147709
# Iteration 1, inertia 174.70199648116983
# Iteration 2, inertia 174.30515542356392
# Converged at iteration 2: center shift 5.4013203265408716e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 251.8758464137917
# Iteration 1, inertia 190.1433795263099
# Iteration 2, inertia 188.15009304014998
# Iteration 3, inertia 183.3685071629072
# Iteration 4, inertia 179.08871443549765
# Iteration 5, inertia 178.106554940368
# Converged at iteration 5: center shift 9.699722394291123e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 249.81151932444658
# Iteration 1, inertia 176.11497572371155
# Iteration 2, inertia 174.8716944473905
# Converged at iteration 2: center shift 7.434357632981309e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 203.37045295673872
# Iteration 1, inertia 151.50582988072293
# Iteration 2, inertia 150.33260117772141
# Converged at iteration 2: center shift 9.20271363274019e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 197.05418733786706
# Iteration 1, inertia 159.65355829197864
# Iteration 2, inertia 155.59482404536132
# Iteration 3, inertia 154.386015482235
# Iteration 4, inertia 153.92847390503704
# Converged at iteration 4: center shift 5.1343227127206724e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 199.0669678676204
# Iteration 1, inertia 167.40286977165016
# Iteration 2, inertia 164.60712720883035
# Iteration 3, inertia 163.60614720958864
# Iteration 4, inertia 163.09484212273273
# Iteration 5, inertia 162.66382989919782
# Iteration 6, inertia 162.3626050703702
# Converged at iteration 6: center shift 8.23795568788669e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 194.64100833428813
# Iteration 1, inertia 150.74852472888406
# Iteration 2, inertia 149.5733854303274
# Iteration 3, inertia 149.253263308617
# Iteration 4, inertia 149.13658314622324
# Converged at iteration 4: center shift 3.9328979048020735e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 188.17494062497263
# Iteration 1, inertia 164.09171971951065
# Iteration 2, inertia 161.54118378105383
# Iteration 3, inertia 160.10227071326256
# Iteration 4, inertia 159.27838393368177
# Iteration 5, inertia 158.73964256278072
# Iteration 6, inertia 158.336615160443
# Iteration 7, inertia 158.04799791877653
# Iteration 8, inertia 157.73222811419566
# Iteration 9, inertia 157.36295794283956
# Iteration 10, inertia 157.0572099712233
# Converged at iteration 10: center shift 7.987350994657375e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 213.35525295525332
# Iteration 1, inertia 163.78146305380838
# Iteration 2, inertia 159.9458235361979
# Iteration 3, inertia 158.19791448823196
# Iteration 4, inertia 157.53771729456832
# Converged at iteration 4: center shift 8.898212200153531e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 251.13884580203273
# Iteration 1, inertia 166.4302825977004
# Iteration 2, inertia 164.63346096931934
# Iteration 3, inertia 163.97503853572778
# Iteration 4, inertia 163.63580581928267
# Converged at iteration 4: center shift 7.961567890038764e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 206.20372034652786
# Iteration 1, inertia 165.54002675513948
# Iteration 2, inertia 164.3114574639278
# Iteration 3, inertia 163.86042342895803
# Iteration 4, inertia 163.55081250475385
# Converged at iteration 4: center shift 7.321876755633491e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 215.16095648956195
# Iteration 1, inertia 158.4108417335658
# Iteration 2, inertia 154.98480977750478
# Iteration 3, inertia 153.4549305861
# Iteration 4, inertia 152.56066344276616
# Iteration 5, inertia 152.0628746940842
# Iteration 6, inertia 151.79687324575175
# Converged at iteration 6: center shift 4.606715187968719e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 239.73918751965635
# Iteration 1, inertia 166.8019702498494
# Iteration 2, inertia 164.32276867876436
# Iteration 3, inertia 164.1400183144521
# Converged at iteration 3: center shift 8.056229247360196e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 195.8863772804632
# Iteration 1, inertia 140.71783311620112
# Iteration 2, inertia 138.65347895769293
# Iteration 3, inertia 137.5788270153784
# Iteration 4, inertia 136.78858169623055
# Iteration 5, inertia 136.20727333515833
# Iteration 6, inertia 135.82692141401196
# Converged at iteration 6: center shift 6.039554838489314e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 188.65999852154908
# Iteration 1, inertia 144.66687749611611
# Iteration 2, inertia 143.14973605464237
# Iteration 3, inertia 142.78424417683152
# Iteration 4, inertia 142.601035381145
# Converged at iteration 4: center shift 7.646713075989693e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 158.37719654492287
# Iteration 1, inertia 134.39616350084276
# Iteration 2, inertia 132.64445723328936
# Iteration 3, inertia 131.76557198981988
# Iteration 4, inertia 131.21364794468477
# Iteration 5, inertia 130.83693122103392
# Converged at iteration 5: center shift 8.944260735256658e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 195.5294694770555
# Iteration 1, inertia 143.0820406919377
# Iteration 2, inertia 142.1602961858054
# Converged at iteration 2: center shift 5.14429947541323e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 163.43495086856558
# Iteration 1, inertia 137.95347531334554
# Iteration 2, inertia 136.701800585839
# Iteration 3, inertia 136.02240834086473
# Iteration 4, inertia 135.5986510047402
# Iteration 5, inertia 135.34375551826315
# Iteration 6, inertia 135.21297625793034
# Converged at iteration 6: center shift 7.463980962254206e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 228.10166272923317
# Iteration 1, inertia 151.4810165441341
# Iteration 2, inertia 147.44216457506158
# Iteration 3, inertia 146.02276978753994
# Iteration 4, inertia 145.46184764451272
# Iteration 5, inertia 145.11823356780644
# Converged at iteration 5: center shift 8.148809869727974e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 179.40343404595296
# Iteration 1, inertia 150.00671039802413
# Iteration 2, inertia 149.14201863216095
# Iteration 3, inertia 148.59832065985216
# Iteration 4, inertia 147.9644939347946
# Iteration 5, inertia 147.322207262498
# Iteration 6, inertia 146.66751832165087
# Iteration 7, inertia 145.98911835681383
# Iteration 8, inertia 144.9550216718194
# Iteration 9, inertia 142.89260242612207
# Iteration 10, inertia 139.87865136727726
# Iteration 11, inertia 137.22955317456476
# Iteration 12, inertia 135.79635319655046
# Iteration 13, inertia 134.65336758965373
# Iteration 14, inertia 134.51631172165588
# Converged at iteration 14: center shift 1.608169695023186e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 181.6246516230177
# Iteration 1, inertia 137.0411972987053
# Iteration 2, inertia 133.62001523759753
# Iteration 3, inertia 131.90455045925586
# Iteration 4, inertia 131.11241276879235
# Iteration 5, inertia 130.7168601828174
# Iteration 6, inertia 130.50035494200876
# Converged at iteration 6: center shift 8.961132554615876e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 183.13998170811368
# Iteration 1, inertia 141.04865147115453
# Iteration 2, inertia 139.51387233398822
# Iteration 3, inertia 139.09590230601097
# Converged at iteration 3: center shift 7.455852654532313e-05 within tolerance 0.00010055299062757338.
# Initialization complete
# Iteration 0, inertia 186.45121781462458
# Iteration 1, inertia 149.94393748481752
# Iteration 2, inertia 149.3168472673619
# Converged at iteration 2: center shift 7.100068455236886e-05 within tolerance 0.00010055299062757338.

# %%
plt.figure(figsize=(8,5))
plt.title('Kmeans: Comparaison de la somme des inerties en fonction du nombre de clusters')
plt.xlabel('Nombre de clusters')
plt.ylabel('Inertie')
ax = sns.lineplot(list(inertia.keys()), list(inertia.values()))
fig = ax.get_figure()
fig.savefig("Inertie en fonction du nombre de cluster KMeans_80-140kv", dpi=400)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# On a un coude à 2 et 4 clusters

# %% [markdown]
# Métric d'efficacité du clustering : Coefficient de silhouette

# %%
silhouettes_kmeans = {}
for i in range(2,6):
    silhouettes_kmeans[i] = silhouette_score(X = df_UH_energy_norm_sample, labels= list(dict_kmeans[(i)].labels_))

# %%
plt.figure(figsize=(8,6)),
plt.title('Coefficient de silhouette moyen en fonction du nombre de clusters (kmeans)')
ax = sns.scatterplot(x = list(silhouettes_kmeans.keys()), y = list(silhouettes_kmeans.values()))
plt.xlabel('Nombre de clusters')
plt.ylabel('Coefficient de silhouette')
fig = ax.get_figure()
fig.savefig("Coef silhouette en fonction du nombre de cluster KMeans_80-140kv", dpi=400)
plt.show()

# %% [markdown]
# Le nombre de cluster permettant d'obtenir le meilleur coefficient de silhouette est de 4

# %% [markdown]
# Métric d'efficacité du clustering : score de davies boulin

# %%
davies_bouldin_kmeans = {}
for i in range(2,10):
    davies_bouldin_kmeans[i] = davies_bouldin_score(X = df_UH_energy_norm_sample, labels= list(dict_kmeans[(i)].labels_))

# %%
plt.figure(figsize=(8,6)),
plt.title('Score de Davis Bouldin en fonction du nombre de clusters (kmeans)')
ax = sns.scatterplot(x = list(davies_bouldin_kmeans.keys()), y = list(davies_bouldin_kmeans.values()))
plt.xlabel('Nombre de clusters')
plt.ylabel('Score de Davis Bouldin')
fig = ax.get_figure()
fig.savefig("Score davis Bouldin en fonction du nombre de cluster KMeans_80-140kv", dpi=400)
plt.show()

# %% [markdown]
# Comme pour l'analyse des inerties, le nombre de clusters idéal pour le score de Davis bouldin est 4.

# %% [markdown]
# Représentation T-SNE

# %%
tsne = TSNE(n_components=2, perplexity = 30)
T = tsne.fit_transform(df_UH_energy_norm_sample.copy())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
plt.figure(figsize=(8,8))
plt.title('Représentation T-SNE de la séparation du jeu de données via KMeans (4 clusters)')
ax = sns.scatterplot(T[:,0], T[:,1], hue=dict_kmeans[(4)].labels_, legend='full', palette = custom_palette[:4])
fig = ax.get_figure()
fig.savefig("T-SNE KMeans_4clusters_80-140kv", dpi=400)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Clustering Hiérarchique

# %% [markdown]
# Pour le clustering hiérarchique, je fais varier le nombre de cluster et je regarde le score de silhouette ainsi que le nombre de cluster proposé

# %%
score_silhouette = []
score_davies_bouldin_clust_hiérar = []
nb_cluster_Clust_hier = []
for i in range(8):
    Clust_hierarchique = AgglomerativeClustering(n_clusters = i+2).fit(df_UH_energy_norm_sample)
    nb_cluster_Clust_hier.append(i+2)
    score_silhouette.append(silhouette_score(X = df_UH_energy_norm_sample, labels= Clust_hierarchique.labels_))
    score_davies_bouldin_clust_hiérar.append(davies_bouldin_score(X = df_UH_energy_norm_sample, labels= Clust_hierarchique.labels_))

# %%
plt.figure(figsize=(8,6)),
plt.title('Coefficient de silhouette moyen en fonction du nombre de clusters (Clustering Hiérarchique)')
ax = sns.scatterplot(x = nb_cluster_Clust_hier, y = score_silhouette)
plt.xlabel('Nombre de clusters')
plt.ylabel('Coefficient de silhouette')
fig = ax.get_figure()
fig.savefig("Coef silhouette en fonction du nombre de cluster Clustering Hiérarchique_80-140kv", dpi=400)
plt.show()

# %% [markdown]
# Un nombre de cluster de 4 semble être optimal au niveau du score de silhouette et potentiellement intéressant pour notre segmentation

# %%
plt.figure(figsize=(8,6)),
plt.title('Score de Davis Bouldin en fonction du nombre de clusters (Clusering hiérarchique)')
ax = sns.scatterplot(x = np.arange(1,9), y = score_davies_bouldin_clust_hiérar)
plt.xlabel('Nombre de clusters')
plt.ylabel('Score de Davis Bouldin')
fig = ax.get_figure()
fig.savefig("Score davis Bouldin en fonction du nombre de cluster Clust-hiérarchique_80-140kv", dpi=400)
plt.show()

# %% [markdown]
# Ce nombre de cluster de 3-4 semble être optimal ausi au niveau du score de Davis Bouldin

# %%
Clust_hierarchique = AgglomerativeClustering(n_clusters = 4).fit(df_UH_energy_norm_sample)

# %%
plt.figure(figsize=(8,8))
plt.title('Représentation de la séparation des données du clustering hiérarchique via T-SNE')
ax = sns.scatterplot(T[:,0], T[:,1], Clust_hierarchique.labels_, palette = custom_palette[:4])
fig = ax.get_figure()
fig.savefig("T-SNE Clustering hiérarchique_80-140kv", dpi=400)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Analyse du clutering en fonction des labels initiaux

# %% [markdown]
# ## Création des databases des résultats

# %%
Clust_hierarchique.labels_.shape

# %%
df_UH_energy_sample = df_UH_energy.sample(int(df_UH_energy.shape[0]/10), random_state=7).copy()

# %%
final_df_UH_clust  = df_UH_energy_sample
final_df_UH_clust["Clustering_hiérarchique"] = Clust_hierarchique.labels_
final_df_UH_clust["Clustering_Kmeans"] = dict_kmeans[(4)].labels_
final_df_UH_clust

# %%
df_results_keams = pad.DataFrame(index = ["Label 1", "Label 2", "Label 3", "Label 4"])
df_results_clu_hiérar = pad.DataFrame(index = ["Label 1", "Label 2", "Label 3", "Label 4"])

# %%
list_quant_feat = ['80', '140']

# %% [markdown]
# Pour connaitre le nombre de point par label

# %%
print("Nombre de point par label pour le Clustering KMeans : ") 
for elm in final_df_UH_clust['Clustering_Kmeans'].unique():
    print(len(final_df_UH_clust[final_df_UH_clust['Clustering_Kmeans'] == elm]['140']))

print("Nombre de point par label pour le Clustering hiérarchique : ")   
for elm in final_df_UH_clust['Clustering_hiérarchique'].unique():
    print(len(final_df_UH_clust[final_df_UH_clust['Clustering_hiérarchique'] == elm]['140']))

# %%
def print_results_segmentation(feature, clustering):
    print("Pour la classification " + str(clustering) + " est le feature " + str(feature))

    if clustering == "Clustering_Kmeans":
      results= []
      for elm in range(4):
        print("La moyenne du label " + str(elm) + " est de " +str(final_df_UH_clust[final_df_UH_clust[clustering] == elm][feature].mean()))
        results.append(final_df_UH_clust[final_df_UH_clust[clustering] == elm][feature].mean())
      df_results_keams[feature] = results

    if clustering == "Clustering_hiérarchique":
      results= []
      for elm in range(4):
        print("La moyenne du label " + str(elm) + " est de " +str(final_df_UH_clust[final_df_UH_clust[clustering] == elm][feature].mean()))
        results.append(final_df_UH_clust[final_df_UH_clust[clustering] == elm][feature].mean())
      df_results_clu_hiérar[feature] = results

# %%
for elm in list_quant_feat:
    print_results_segmentation(elm, "Clustering_Kmeans")
    print_results_segmentation(elm, "Clustering_hiérarchique")

# %%
df_results_keams

# %%
df_results_clu_hiérar

# %% [markdown]
# ## Réprésentation graphique des variables d'intérêts

# %%
custom_palette = [sns.xkcd_rgb["windows blue"], sns.xkcd_rgb["pale red"], sns.xkcd_rgb["medium green"], "orange", "blue","yellow", "purple", "deeppink", "brown", "teal", "black"] 
sns.set_palette(custom_palette)

# %% [markdown]
# KMeans

# %%
plt.figure(figsize=(10, 6))
ax = sns.barplot(x = final_df_UH_clust["Clustering_Kmeans"], y = final_df_UH_clust["140"].values, orient='v', palette = custom_palette)
ax.set_xlabel("Clustering Kmeans")
ax.set_ylabel('UH')
ax.set_xticklabels(ax.get_xticklabels())
figure = ax.get_figure()
figure.savefig("Clustering KMeans 80-140kv", dpi=400)

# %%
plt.figure(figsize=(10, 6))
ax = sns.barplot(x = final_df_UH_clust["Clustering_hiérarchique"], y = final_df_UH_clust["140"].values, orient='v', palette = custom_palette)
ax.set_xlabel("Clustering clustering hiérarchique")
ax.set_ylabel('UH')
ax.set_xticklabels(ax.get_xticklabels())
figure = ax.get_figure()
figure.savefig("Clustering clustering hiérarchique 80-140kv", dpi=400)

# %% [markdown]
# # Comparaison des segmentations avec la réalité

# %%
df

# %%
final_df_UH_clust

# %%
df_comparaison = pad.merge(df, final_df_UH_clust.drop(['80', '140'], axis=1), left_index=True, right_index=True)

# %%
adjusted_rand_score(df_comparaison['label'], df_comparaison['Clustering_Kmeans'])

# %% [markdown]
# ## Test en forcant le KMeans à nous donner 17 labels (nombre d'insert réel)

# %%
kmeans = KMeans(n_clusters=17, verbose=1, random_state=7).fit(df_UH_energy_norm_sample)

# %%
kmeans.labels_

# %%
df_comparaison.insert(loc = 8, column = "Clustering_Kmeans_17labels", value = kmeans.labels_)

# %%
df_comparaison

# %%
adjusted_rand_score(df_comparaison['label'], df_comparaison['Clustering_Kmeans_17labels'])

# %% [markdown]
# Le résultat n'est pas probant du tout comme escompté

# %%
df_sample = df.sample(int(df.shape[0]/20), random_state=7).copy()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
#générer la matrice des liens
Z = linkage(df_sample,method='ward',metric='euclidean')

# %%
#affichage du dendrogramme
plt.title("CAH")
dendrogram(Z,labels=df_sample.index,orientation='left',color_threshold=0)
plt.show()
